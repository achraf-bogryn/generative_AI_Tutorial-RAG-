# %% [markdown]
# # Ollama Embedding

# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embeddings = (
    OllamaEmbeddings(model="gemma:2b")
)

# %%
embeddings
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma:2b', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1=embeddings.embed_documents(
[
    "To such a task we can dedicate our lives and our fortunes, everything that we are and everything that we have",
    "is a distressing and oppressive duty, gentlemen of the Congress, which I have performed in thus addressing you.",
]
)

r1
# Out:
# [[-0.951967179775238,
#   -0.42955437302589417,
#   0.17678260803222656,
#   0.6271649599075317,
#   -1.3419861793518066,
#   0.03153511881828308,
#   -0.4838729798793793,
#   0.3762013018131256,
#   0.708523690700531,
#   1.4827265739440918,
#   0.6656259298324585,
#   1.1292290687561035,
#   -0.15647317469120026,
#   1.8429715633392334,
#   -0.9890397787094116,
#   1.1226451396942139,
#   -0.9083480834960938,
#   0.2706407606601715,
#   -0.49178189039230347,
#   0.7207220792770386,
#   1.5613449811935425,
#   -0.5887894034385681,
#   -0.5939841270446777,
#   1.7010315656661987,
#   0.0984187051653862,
#   0.666040301322937,
#   -0.3121708631515503,
#   0.2794116139411926,
#   1.136436939239502,
#   0.3357703387737274,
#   -0.15176808834075928,
#   -1.1296899318695068,
#   -0.17522399127483368,
#   -2.142852306365967,
#   -1.144155502319336,
#   1.0026203393936157,
#   0.6608927249908447,
#   -0.8733928799629211,
#   0.23866459727287292,
#   -1.3279045820236206,
# ...

# %%
len(r1[0])
# Out:
# 2048

# %%
text = "To such a task we can dedicate our lives and our fortunes, everything that we are and everything that we have"
query_result = embeddings.embed_query(text)

# %%
len(query_result)
# Out:
# 2048
